# %%
# %load_ext autoreload
# %autoreload 2

# %%
from cvx_opt.hw6 import problem_1, problem_2_3
from pathlib import Path

# %%
# SAVE_DIR = Path("/Users/sean/code/study-hard/cvx-opt/latex/hw6/Images")
SAVE_DIR = None

# %%
problem_1(SAVE_DIR)

# %%
problem_2_3(SAVE_DIR)
# Out:
# Gradient Descent converged: True
# True
