# %%
from initial_data_wrangling import load_dni_data, load_load_data
import numpy as np
import matplotlib.pyplot as plt

# %%
def total_seconds(timedelta):
    return timedelta.astype("timedelta64[s]").astype(float)

# %%
def interp(load, dni):
    load_t = total_seconds(load['time'] - load['time'][0]) / 60  # min
    dni_t = total_seconds(dni['time'] - dni['time'][0]) / 60  # min
    dni_t -= 7 * 60  # UTC -> PDT

    dnis = np.interp(load_t, dni_t, np.mean(dni['dnis'], axis=1))
    load_power = load["power"]
    solar_pu = dnis / 1000
    return load_t, load_power, solar_pu

# %%
def filter_days(start_day, num_days, load_t, load, solar_pu):
    min_per_day = 60 * 24
    t_start = start_day * min_per_day
    t_end = t_start + num_days * min_per_day  # 1day * 60 min/hr * 24hr/day
    times = np.logical_and(load_t <= t_end, load_t >= t_start)
    load_t = load_t[times]
    load = load[times]
    solar_pu = solar_pu[times]
    return load_t, load, solar_pu

# %%
start_day = 0
num_days = 1
load = load_load_data()
dni = load_dni_data()
load_t, load, solar_pu = interp(load, dni)
load_t, load, solar_pu = filter_days(start_day, num_days, load_t, load, solar_pu)

# %%
plt.figure()
plt.plot(load_t / 60 - start_day * 24, load, label='load')
plt.plot(load_t / 60 - start_day * 24, solar_pu * 50, label='solar')
plt.legend()

# %%
MWh_per_MW = 4
solar_power_installed = 100 # MW
geothermal_installed = 40  # MW
battery_capacity = 400 * MWh_per_MW  # MWh
design = np.array([
    solar_power_installed,
    geothermal_installed,
    battery_capacity
])

# For ratio 1 MW : 4 hr
# Cost for 4 MWh
# 350k/MW + 4 * 300k/MWh / 4 MWh/MW
cost_pu = np.array([
    1250,   # k/MW
    3500,   # k/MW
    (350 / MWh_per_MW + 300)  # k/MWh
])

# %%
def capital_cost(design, cost_pu):
    """
    Price in 1,000s of USD of capital expenditures of design.
    
    Arguments:
        design: 3-vector of [solar capacity (MW), geothermal capacity (MW), battery capacity (MWh)]
        cost_pu: 3-vector of cost per MW (MWh) of each of the preceding
    """
    return np.sum(design * cost_pu)

# %%
total_capital_cost = capital_cost(design, cost_pu) / 1000  # million USD
print(f"Capital cost of design: {total_capital_cost} million USD")
# Out:
# Capital cost of design: 885.0 million USD

# %%
# def control_constraints(design, solar_pu):
#     """Constraints of controllable generation as a function of time.
    
#     Arguments: 
#         design: [solar, geothermal, battery]
    
#     Returns:
#         Ut: (T, R^X) -> R^(U x 2): function from time index, state variable
#             to a matrix of control constraints with the first column representing
#             the minimum value for each control u_i, and the second column
#             representing the maximum.
#     """
#     P = design[0]
#     E = design[2]
#     def U_t(t, x):
#         return np.array([
#             [0, P * solar_pu[t]],
#             [x - E, x]
#         ])
#     return U_t

# %%
class SampleSpace:
    def __init__(self, design, n_u, delta_t, T_max, w, solar_pu):
        self.design = design
        self.n_u = n_u
        self.N_x, self.N_u = self.find_dims(n_u, T_max, delta_t)
        self.N_T = w.shape[0]
        self.delta_t = delta_t
        self.T_max = T_max
        self.w = w
        self.solar_pu = solar_pu
        self.J = np.arange(0, self.N_u)
        self.X, self.U = self.discretize()
        
    def find_dims(self, n_u, T_max, delta_t):
        assert isinstance(n_u, int)
        assert n_u > 0
        N_x = np.floor(T_max / delta_t).astype(int) * n_u
        N_u = 2 * n_u + 1
        return N_x, N_u
        
    def discretize(self):

        X = np.linspace(0, self.design[2], self.N_x)
        delta_x = X[1] - X[0]
        print("X:", X)
        # N_x x N_u
        U_1 = np.full((self.N_x, self.N_u), np.nan)
        for i in range(self.N_x):
            j = self.j_slice(i)
            U_1[i, j] = delta_x / self.delta_t * (self.J[j] - self.n_u)

        # Convert everything to dim 3: N_T x N_x x N_u
        U_1 = np.expand_dims(U_1, axis=(0,))
        w = np.expand_dims(self.w, axis=(1,2))
        solar_pu = np.expand_dims(self.solar_pu, axis=(1,2))
        U_0 = np.clip(w - U_1, 0, solar_pu * self.design[0])
        U = np.concatenate([
            U_0[..., np.newaxis],
            np.repeat(U_1[..., np.newaxis], self.N_T, axis=0)
        ], axis=-1)
        return X, U
    
    def j_slice(self, i):
        return slice(
            max(0, self.n_u + i + 1 - self.N_x),
            min(2 * self.n_u + 1, self.n_u + i + 1)
        )
    
    def j(self, i):
        return self.J[self.j_slice(i)]

# %%
dt = np.mean(np.diff(load_t)) / 60  # hour
# Steps to fully (dis)charge battery at max rate
T_max = MWh_per_MW  # hours
print("Steps to fully (dis)charge battery: ", np.floor(T_max / dt).astype(int))
n_u = 10
w = load - design[1]
sample = SampleSpace(design, n_u, dt, T_max, w, solar_pu)
print("X_sample shape:", sample.X.shape)
print("U_sample shape (N_T x N_X x N_U x U):", sample.U.shape)
# Out:
# Steps to fully (dis)charge battery:  48
# X: [   0.            3.34029228    6.68058455   10.02087683   13.3611691
#    16.70146138   20.04175365   23.38204593   26.7223382    30.06263048
#    33.40292276   36.74321503   40.08350731   43.42379958   46.76409186
#    50.10438413   53.44467641   56.78496868   60.12526096   63.46555324
#    66.80584551   70.14613779   73.48643006   76.82672234   80.16701461
#    83.50730689   86.84759916   90.18789144   93.52818372   96.86847599
#   100.20876827  103.54906054  106.88935282  110.22964509  113.56993737
#   116.91022965  120.25052192  123.5908142   126.93110647  130.27139875
#   133.61169102  136.9519833   140.29227557  143.63256785  146.97286013
#   150.3131524   153.65344468  156.99373695  160.33402923  163.6743215
#   167.01461378  170.35490605  173.69519833  177.03549061  180.37578288
#   183.71607516  187.05636743  190.39665971  193.73695198  197.07724426
#   200.41753653  203.75782881  207.09812109  210.43841336  213.77870564
#   217.11899791  220.45929019  223.79958246  227.13987474  230.48016701
#   233.82045929  237.16075157  240.50104384  243.84133612  247.18162839
#   250.52192067  253.86221294  257.20250522  260.54279749  263.88308977
#   267.22338205  270.56367432  273.9039666   277.24425887  280.58455115
#   283.92484342  287.2651357   290.60542797  293.94572025  297.28601253
#   300.6263048   303.96659708  307.30688935  310.64718163  313.9874739
        )
        print('j:', j)
        print('i_next:', i_next)
        print('ushape:', u.shape)
        cost = (
            1/2 * c_load_lost * (np.sum(u, axis=1) - w[t]) ** 2
            + J[t + 1, i_next]
        )
        J[t, i] = np.min(cost)
        u_star[t, i] = j.start + np.argmin(cost)
        # State = X[i]
#         for j in range(n_slots):
#             # Actions = U[j]
#             x, u = state_action(i, j)
#             i_tp1 = n_slots - j
#             solar = solar_from_battery(t, u, w)
#             f_op = 1/2 * c_load_lost * (solar + u - w[t]) ** 2
#             J_future_opt = J[n_slots - 1 - j, t + 1]
#             cost_total = f_op + J_future_opt
#             if cost_total < J[i, t]:
#                 J[i, t] = cost_total
#                 u_star[i, t] = u
            
            
            
            
            
    # X x T
#     J_min_next = np.min(J[:, :, t + 1], axis=1)
#     U_
# Out:
# j: slice(0, 11, None)
# i_next: slice(0, 11, None)
# ushape: (11, 2)
# j: slice(0, 12, None)
# i_next: slice(0, 12, None)
# ushape: (12, 2)
# j: slice(0, 13, None)
# i_next: slice(0, 13, None)
# ushape: (13, 2)
# j: slice(0, 14, None)
# i_next: slice(0, 14, None)
# ushape: (14, 2)
# j: slice(0, 15, None)
# i_next: slice(0, 15, None)
# ushape: (15, 2)
# j: slice(0, 16, None)
# i_next: slice(0, 16, None)
# ushape: (16, 2)
# j: slice(0, 17, None)
# i_next: slice(0, 17, None)
# ushape: (17, 2)
# j: slice(0, 18, None)
# i_next: slice(0, 18, None)
# ushape: (18, 2)
# j: slice(0, 19, None)
# i_next: slice(0, 19, None)
# ushape: (19, 2)
# j: slice(0, 20, None)
# i_next: slice(0, 20, None)
# ushape: (20, 2)
# j: slice(0, 21, None)
# i_next: slice(0, 21, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(1, 22, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(2, 23, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(3, 24, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(4, 25, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(5, 26, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(6, 27, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(7, 28, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(8, 29, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(9, 30, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(10, 31, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(11, 32, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(12, 33, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(13, 34, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(14, 35, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(15, 36, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(16, 37, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(17, 38, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(18, 39, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(19, 40, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(20, 41, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(21, 42, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(22, 43, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(23, 44, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(24, 45, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(25, 46, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(26, 47, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(27, 48, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(28, 49, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(29, 50, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(30, 51, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(31, 52, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(32, 53, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(33, 54, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(34, 55, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(35, 56, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(36, 57, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(37, 58, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(38, 59, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(39, 60, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(40, 61, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(41, 62, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(42, 63, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(43, 64, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(44, 65, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(45, 66, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(46, 67, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(47, 68, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(48, 69, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(49, 70, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(50, 71, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(51, 72, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(52, 73, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(53, 74, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(54, 75, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(55, 76, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(56, 77, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(57, 78, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(58, 79, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(59, 80, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(60, 81, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(61, 82, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(62, 83, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(63, 84, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(64, 85, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(65, 86, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(66, 87, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(67, 88, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(68, 89, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(69, 90, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(70, 91, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(71, 92, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(72, 93, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(73, 94, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(74, 95, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(75, 96, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(76, 97, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(77, 98, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(78, 99, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(79, 100, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(80, 101, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(81, 102, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(82, 103, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(83, 104, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(84, 105, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(85, 106, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(86, 107, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(87, 108, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(88, 109, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice
None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(298, 319, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(299, 320, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(300, 321, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(301, 322, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(302, 323, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(303, 324, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(304, 325, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(305, 326, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(306, 327, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(307, 328, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(308, 329, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(309, 330, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(310, 331, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(311, 332, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(312, 333, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(313, 334, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(314, 335, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(315, 336, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(316, 337, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(317, 338, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(318, 339, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(319, 340, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(320, 341, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(321, 342, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(322, 343, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(323, 344, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(324, 345, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(325, 346, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(326, 347, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(327, 348, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(328, 349, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(329, 350, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(330, 351, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(331, 352, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(332, 353, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(333, 354, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(334, 355, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(335, 356, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(336, 357, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(337, 358, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(338, 359, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(339, 360, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(340, 361, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(341, 362, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(342, 363, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(343, 364, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(344, 365, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(345, 366, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(346, 367, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(347, 368, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(348, 369, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(349, 370, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(350, 371, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(351, 372, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(352, 373, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(353, 374, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(354, 375, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(355, 376, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(356, 377, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(357, 378, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(358, 379, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(359, 380, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(360, 381, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(361, 382, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(362, 383, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(363, 384, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(364, 385, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(365, 386, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(366, 387, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(367, 388, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(368, 389, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(369, 390, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(370, 391, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(371, 392, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(372, 393, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(373, 394, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(374, 395, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(375, 396, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(376, 397, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(377, 398, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(378, 399, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(379, 400, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(380, 401, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(381, 402, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(382, 403, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(383, 404, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(384, 405, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(385, 406, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(386, 407, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(387, 408, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(388, 409, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(389, 410, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(390, 411, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(391, 412, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(392, 413, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(393, 414, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(394, 415, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(395, 416, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(396, 417, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(397, 418, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(398, 419, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(399, 420, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(400, 421, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(401, 422, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(402, 423, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(403, 424, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(404, 425, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(405, 426, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(406, 427, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(407, 428, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(408, 429, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(409, 430, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(410, 431, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(411, 432, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(412, 433, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(413, 434, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(414, 435, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(415, 436, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(416, 437, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(417, 438, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(418, 439, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(419, 440, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(420, 441, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(421, 442, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(422, 443, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(423, 444, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(424, 445, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(425, 446, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(426, 447, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(427, 448, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(428, 449, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(429, 450, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(430, 451, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(431, 452, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(432, 453, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(433, 454, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(434, 455, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(435, 456, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(436, 457, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(437, 458, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(438, 459, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(439, 460, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(440, 461, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(441, 462, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(442, 463, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(443, 464, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(444, 465, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(445, 466, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(446, 467, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(447, 468, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(448, 469, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(449, 470, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(450, 471, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(451, 472, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(452, 473, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(453, 474, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(454, 475, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(455, 476, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(456, 477, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(457, 478, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(458, 479, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(459, 480, None)
# ushape: (21, 2)
# j: slice(1, 21, None)
# i_next: slice(460, 480, None)
# ushape: (20, 2)
# j: slice(2, 21, None)
# i_next: slice(461, 480, None)
# ushape: (19, 2)
# j: slice(3, 21, None)
# i_next: slice(462, 480, None)
# ushape: (18, 2)
# j: slice(4, 21, None)
# i_next: slice(463, 480, None)
# ushape: (17, 2)
# j: slice(5, 21, None)
# i_next: slice(464, 480, None)
# ushape: (16, 2)
# j: slice(6, 21, None)
# i_next: slice(465, 480, None)
# ushape: (15, 2)
# j: slice(7, 21, None)
# i_next: slice(466, 480, None)
# ushape: (14, 2)
# j: slice(8, 21, None)
# i_next: slice(467, 480, None)
# ushape: (13, 2)
# j: slice(9, 21, None)
# i_next: slice(468, 480, None)
# ushape: (12, 2)
# j: slice(10, 21, None)
# i_next: slice(469, 480, None)
# ushape: (11, 2)
# j: slice(0, 11, None)
# i_next: slice(0, 11, None)
# ushape: (11, 2)
# j: slice(0, 12, None)
# i_next: slice(0, 12, None)
# ushape: (12, 2)
# j: slice(0, 13, None)
# i_next: slice(0, 13, None)
# ushape: (13, 2)
# j: slice(0, 14, None)
# i_next: slice(0, 14, None)
# ushape: (14, 2)
# j: slice(0, 15, None)
# i_next: slice(0, 15, None)
# ushape: (15, 2)
# j: slice(0, 16, None)
# i_next: slice(0, 16, None)
# ushape: (16, 2)
# j: slice(0, 17, None)
# i_next: slice(0, 17, None)
# ushape: (17, 2)
# j: slice(0, 18, None)
# i_next: slice(0, 18, None)
# ushape: (18, 2)
# j: slice(0, 19, None)
# i_next: slice(0, 19, None)
# ushape: (19, 2)
# j: slice(0, 20, None)
# i_next: slice(0, 20, None)
# ushape: (20, 2)
# j: slice(0, 21, None)
# i_next: slice(0, 21, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(1, 22, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(2, 23, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(3, 24, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(4, 25, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(5, 26, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(6, 27, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(7, 28, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(8, 29, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(9, 30, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(10, 31, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(11, 32, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(12, 33, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(13, 34, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(14, 35, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(15, 36, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(16, 37, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(17, 38, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(18, 39, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(19, 40, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(20, 41, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(21, 42, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(22, 43, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(23, 44, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(24, 45, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(25, 46, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(26, 47, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(27, 48, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(28, 49, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(29, 50, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(30, 51, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(31, 52, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(32, 53, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(33, 54, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(34, 55, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(35, 56, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(36, 57, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(37, 58, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(38, 59, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(39, 60, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(40, 61, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(41, 62, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(42, 63, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(43, 64, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(44, 65, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(45, 66, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(46, 67, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(47, 68, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(48, 69, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(49, 70, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(50, 71, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(51, 72, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(52, 73, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(53, 74, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(54, 75, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(55, 76, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(56, 77, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(57, 78, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(58, 79, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(59, 80, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(60, 81, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(61, 82, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(62, 83, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(63, 84, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(64, 85, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(65, 86, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(66, 87, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(67, 88, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(68, 89, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(69, 90, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(70, 91, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(71, 92, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(72, 93, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(73, 94, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(74, 95, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(75, 96, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(76, 97, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(77, 98, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(78, 99, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(79, 100, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(80, 101, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(81, 102, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(82, 103, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(83, 104, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(84, 105, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(85, 106, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(86, 107, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(87, 108, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(88, 109, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(89, 110, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(90, 111, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(91, 112, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(92, 113, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(93, 114, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(94, 115, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(95, 116, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(96, 117, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(97, 118, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(98, 119, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(99, 120, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(100, 121, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(101, 122, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(102, 123, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(103, 124, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(104, 125, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(105, 126, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(106, 127, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(107, 128, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(108, 129, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(109, 130, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(110, 131, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(111, 132, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(112, 133, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(113, 134, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(114, 135, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(115, 136, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(116, 137, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(117, 138, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(118, 139, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(119, 140, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(120, 141, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(121, 142, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(122, 143, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(123, 144, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(124, 145, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(125, 146, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(126, 147, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(127, 148, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(128, 149, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(129, 150, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(130, 151, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(131, 152, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice
None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(352, 373, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(353, 374, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(354, 375, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(355, 376, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(356, 377, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(357, 378, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(358, 379, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(359, 380, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(360, 381, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(361, 382, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(362, 383, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(363, 384, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(364, 385, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(365, 386, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(366, 387, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(367, 388, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(368, 389, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(369, 390, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(370, 391, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(371, 392, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(372, 393, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(373, 394, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(374, 395, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(375, 396, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(376, 397, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(377, 398, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(378, 399, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(379, 400, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(380, 401, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(381, 402, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(382, 403, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(383, 404, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(384, 405, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(385, 406, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(386, 407, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(387, 408, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(388, 409, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(389, 410, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(390, 411, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(391, 412, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(392, 413, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(393, 414, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(394, 415, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(395, 416, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(396, 417, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(397, 418, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(398, 419, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(399, 420, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(400, 421, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(401, 422, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(402, 423, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(403, 424, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(404, 425, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(405, 426, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(406, 427, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(407, 428, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(408, 429, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(409, 430, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(410, 431, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(411, 432, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(412, 433, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(413, 434, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(414, 435, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(415, 436, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(416, 437, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(417, 438, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(418, 439, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(419, 440, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(420, 441, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(421, 442, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(422, 443, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(423, 444, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(424, 445, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(425, 446, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(426, 447, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(427, 448, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(428, 449, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(429, 450, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(430, 451, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(431, 452, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(432, 453, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(433, 454, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(434, 455, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(435, 456, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(436, 457, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(437, 458, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(438, 459, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(439, 460, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(440, 461, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(441, 462, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(442, 463, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(443, 464, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(444, 465, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(445, 466, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(446, 467, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(447, 468, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(448, 469, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(449, 470, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(450, 471, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(451, 472, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(452, 473, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(453, 474, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(454, 475, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(455, 476, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(456, 477, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(457, 478, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(458, 479, None)
# ushape: (21, 2)
# j: slice(0, 21, None)
# i_next: slice(459, 480, None)
# ushape: (21, 2)
# j: slice(1, 21, None)
# i_next: slice(460, 480, None)
# ushape: (20, 2)
# j: slice(2, 21, None)
# i_next: slice(461, 480, None)
# ushape: (19, 2)
# j: slice(3, 21, None)
# i_next: slice(462, 480, None)
# ushape: (18, 2)
# j: slice(4, 21, None)
# i_next: slice(463, 480, None)
# ushape: (17, 2)
# j: slice(5, 21, None)
# i_next: slice(464, 480, None)
# ushape: (16, 2)
# j: slice(6, 21, None)
# i_next: slice(465, 480, None)
# ushape: (15, 2)
# j: slice(7, 21, None)
# i_next: slice(466, 480, None)
# ushape: (14, 2)
# j: slice(8, 21, None)
# i_next: slice(467, 480, None)
# ushape: (13, 2)
# j: slice(9, 21, None)
# i_next: slice(468, 480, None)
# ushape: (12, 2)
# j: slice(10, 21, None)
# i_next: slice(469, 480, None)
# ushape: (11, 2)

# %%
i = np.argmin(J[0])
i_optimal = []
j_optimal = []
for t in range(J.shape[0]):
    # Best action
    j = u_star[t, i]
    i_optimal.append(i)
    j_optimal.append(j)
    i = i + sample.n_u - j

# %%
sample.N_T
# Out:
# 289

# %%
t_range = np.arange(0, sample.N_T)
x_opt = sample.X[i_optimal]
u_opt = sample.U[t_range, i_optimal, j_optimal, :]
J_opt = J[t_range, i_optimal]

# %%
design[2]
# Out:
# 1600

# %%
i_half = int((sample.N_x - 1) / 2)

# %%
t = 0
i = i_half
solar_min = 0
solar_max = solar_pu[t] * design[0]
discharge_max = design[2] / MWh_per_MW
charge_max = - design[2] / MWh_per_MW
box = np.array([
    [solar_min, discharge_max],
    [solar_max, discharge_max],
    [solar_max, charge_max],
    [solar_min, charge_max],
    [solar_min, discharge_max],
])
battery = sample.U[t, i, :, 1]
solar_unconstrained = w[t] - battery
solar = sample.U[t, i, :, 0]
plt.figure()
plt.plot(box[:, 0], box[:, 1], label="Constraints")
plt.plot(solar_unconstrained, battery, label="Unconstrained to balance system")
plt.plot(solar, battery, label="Constrained")
plt.legend()
# batterysample.U[t, i_half, 1]

# %%
plt.figure()
plt.plot(w)

# %%
sample.X.shape
# Out:
# (480,)

# %%
sample.X[1] - sample.X[0]
# Out:
# 3.3402922755741127

# %%
sample.U[0, i_half, 1, 1] - sample.U[0, i_half, 0, 1]
# Out:
# 40.08350730688932

# %%
u_battery[0]
# Out:
# array([-400.83507307, -360.75156576, -320.66805846, -280.58455115,
#        -240.50104384, -200.41753653, -160.33402923, -120.25052192,
#         -80.16701461,  -40.08350731,    0.        ,   40.08350731,
#          80.16701461,  120.25052192,  160.33402923,  200.41753653,
#         240.50104384,  280.58455115,  320.66805846,  360.75156576,
#         400.83507307])

# %%
u_solar = sample.U[:, i_half, :, 0]
u_battery = sample.U[:, i_half, :, 1]
_, plots = plt.subplots(2, 1, sharex=True)
labels = [f"{i}" for i in range(u_solar.shape[1])]
plots[0].plot(u_solar, label=labels)
plots[0].plot(solar_pu * design[0], label='max solar')
plots[1].plot(u_battery, label=labels)
for plot in plots:
    plot.legend()

# %%
t_hr = load_t / 60
_, plots = plt.subplots(2, 2, sharex=True)
plots = [p for row in plots for p in row]
plots[0].plot(t_hr, w, label='load')
plots[0].plot(t_hr, solar_pu * design[0], label='Max solar')
plots[0].plot(t_hr, u_opt[:, 0], label='Solar')
plots[1].plot(t_hr, u_opt[:, 1], label='Charge/discharge')
plots[2].plot(t_hr, x_opt, label='Storage')
plots[3].plot(t_hr, J_opt, label='Cost to go')
for plot in plots:
    plot.legend()

# %%
plt.figure()
plt.plot(J[:, 0])

# %%
J[:, -1]

# %%
plt.figure()
plt.plot(u_star)

# %%
plt.plot(u_star)

# %%
def simulate_system(x0, u):
    """
    Simulate system for a given control u and starting state x0.
    
    Arguments:
        x0 (float): initial battery charge
        u (R^(T x U)): control vector at each time T
        
    Returns:
        x (R^T): State at each time [0, T)
    """
    x = np.full(u.shape[0], np.nan)
    x[0] = x0
    for i in range(u.shape[0] - 1):
        x[i + 1] = x[i] + u[i, 1]
    return x

# %%
np.array([1, 2, 3])**2

# %%
def operational_costs(design, w, c_load_lost):
    u = optimal_control(...)
    return 1/2 * c_load_lost * np.sum((np.sum(u, axis=1) - w)**2)

# %%
plt.figure()
plt.plot(load_t, load['power'])

# %%
list(load.keys())

# %%
dni['time']
